# %%
import numpy as np, pandas as pd


WasteCities = pd.read_csv("wasteCities.csv", index_col=0)

WasteCities
# Out:
#       region_id country_name income_id       city_name  \
# iso3c
# AFG         SAS  Afghanistan       LIC       Jalalabad
# AFG         SAS  Afghanistan       LIC        Kandahar
# AFG         SAS  Afghanistan       LIC  Mazar-E-Sharif
# AFG         SAS  Afghanistan       LIC           Kabul
# AFG         SAS  Afghanistan       LIC         HiratÂ
# ...         ...          ...       ...             ...
# ZWE         SSF     Zimbabwe       LIC        HarareÂ
# ZWE         SSF     Zimbabwe       LIC           Gweru
# ZWE         SSF     Zimbabwe       LIC          Kariba
# ZWE         SSF     Zimbabwe       LIC   Masvingo City
# ZWE         SSF     Zimbabwe       LIC       SakubvaÂ
#
#       additional_data_annual_budget_for_waste_management_year  \
# iso3c
# AFG                                                  NaN
# AFG                                                  NaN
# AFG                                                  NaN
# ...
